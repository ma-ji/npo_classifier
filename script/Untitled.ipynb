# %%
import pandas as pd
import requests
from tqdm import tqdm

# %%
df_by_year=pd.read_csv('https://nccs-data.urban.org/data/core/2015/coreco.core2015co.csv', sep=',')
# Out:
# /tikal/ji/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (1,2,3,4,6,9,12,14,20,22,29,30,31,73,87,95,102,120,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_selected=df_by_year.sample(round(len(df_by_year)/2))[['EIN', 'NTEE1']]

# %%
df_2015_irs=pd.read_json('https://s3.amazonaws.com/irs-form-990/index_2015.json')

# %%
df_index_2015=pd.DataFrame()
for index in tqdm(df_2015_irs.index):
    df_index_2015=pd.concat([df_index_2015, pd.DataFrame.from_dict(df_2015_irs.loc[1, 'Filings2015'], orient='index').T])
# Out:
# 100%|██████████| 261034/261034 [1:21:24<00:00, 53.44it/s]

# %%
df_index_2015
# Out:
#                                               Filings2015
# 0       {'EIN': '390963472', 'TaxPeriod': '201412', 'D...
# 1       {'EIN': '043575807', 'TaxPeriod': '201506', 'D...
# 2       {'EIN': '942796496', 'TaxPeriod': '201412', 'D...
# 3       {'EIN': '592856392', 'TaxPeriod': '201506', 'D...
# 4       {'EIN': '953006805', 'TaxPeriod': '201506', 'D...
# 5       {'EIN': '270964918', 'TaxPeriod': '201412', 'D...
# 6       {'EIN': '752772633', 'TaxPeriod': '201412', 'D...
# 7       {'EIN': '042488505', 'TaxPeriod': '201412', 'D...
# 8       {'EIN': '262082745', 'TaxPeriod': '201412', 'D...
# 9       {'EIN': '231672348', 'TaxPeriod': '201412', 'D...
# 10      {'EIN': '352321648', 'TaxPeriod': '201412', 'D...
# 11      {'EIN': '541083954', 'TaxPeriod': '201411', 'D...
# 12      {'EIN': '770576645', 'TaxPeriod': '201405', 'D...
# 13      {'EIN': '200771894', 'TaxPeriod': '201412', 'D...
# 14      {'EIN': '830333159', 'TaxPeriod': '201410', 'D...
# ...

# %%
df_2015_nccs.loc[[index for index in df_2015_nccs.index if df_2015_nccs.loc[index, 'EIN'] in df_2015_irs['EIN']]]
# Out:
#          EIN TaxPeriod             DLN FormType  \
# 0  043575807    201506  93493239006195      990
#
#                                                  URL  \
# 0  https://s3.amazonaws.com/irs-form-990/20154239...
#
#                                     OrganizationName SubmittedOn  \
# 0  PLYMOUTH REGIONAL ECONOMIC DEVELOPMENT FOUNDAT...  2015-10-06
#
#              ObjectId          LastUpdated
# 0  201542399349300619  2016-03-21T17:23:53

# %%
pd.to_numeric()

# %%
df_irs_990_index=pd.DataFrame.from_items('https://s3.amazonaws.com/irs-form-990/index_2015.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-c99043c1b372> in <module>()
# ----> 1 df_irs_990_index=pd.DataFrame.from_items('https://s3.amazonaws.com/irs-form-990/index_2015.json')
#
# /tikal/ji/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in from_items(cls, items, columns, orient)
#    1259         frame : DataFrame
#    1260         """
# -> 1261         keys, values = lzip(*items)
#    1262
#    1263         if orient == 'columns':
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
for year in range(2011, 2016, 1):
    str(year)
